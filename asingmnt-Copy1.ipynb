# %%
pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in c:\users\nirma\anaconda3\lib\site-packages (4.7.0.72)
# Requirement already satisfied: numpy>=1.17.0 in c:\users\nirma\anaconda3\lib\site-packages (from opencv-python) (1.23.5)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.1.2 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install numpy
# Out:
# Requirement already satisfied: numpy in c:\users\nirma\anaconda3\lib\site-packages (1.23.5)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.1.2 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in c:\users\nirma\anaconda3\lib\site-packages (3.5.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\nirma\anaconda3\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\nirma\anaconda3\lib\site-packages (from matplotlib) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\nirma\anaconda3\lib\site-packages (from matplotlib) (1.4.2)
# Requirement already satisfied: numpy>=1.17 in c:\users\nirma\anaconda3\lib\site-packages (from matplotlib) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\nirma\anaconda3\lib\site-packages (from matplotlib) (21.3)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\nirma\anaconda3\lib\site-packages (from matplotlib) (9.2.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\nirma\anaconda3\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\nirma\anaconda3\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\nirma\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.1.2 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import cv2
import os
import numpy as np
import matplotlib.pyplot as plt

# %%
# Path to your dataset
dataset_path = r'C:\Users\nirma\Downloads\archive (10)\images'

# Load the pre-trained Haar Cascade Classifier for face detection
cascade_path = cv2.data.haarcascades + 'haarcascade_frontalface_default.xml'
face_cascade = cv2.CascadeClassifier(cascade_path)

# Function to detect faces in an image
def detect_faces(image_path):
    # Read the image from the file
    img = cv2.imread(image_path)
    
    # Check if the image is loaded successfully
    if img is None:
        print(f"Error loading image: {image_path}")
        return
    
    # Convert the image to grayscale for processing
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    
    # Detect faces in the grayscale image
    faces = face_cascade.detectMultiScale(
        gray,
        scaleFactor=1.1,
        minNeighbors=5,
        minSize=(30, 30),
        flags=cv2.CASCADE_SCALE_IMAGE
    )
    
    # Draw rectangles around the detected faces
    for (x, y, w, h) in faces:
        cv2.rectangle(img, (x, y), (x + w, y + h), (255, 0, 0), 2)
   
 
    # Display the image with the detected faces
    plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
    plt.axis('off')
    plt.show()

# Loop through the dataset and process each image
for root, dirs, files in os.walk(dataset_path):
    for file in files:
        # Check for valid image file extensions
        if file.endswith(('jpg', 'jpeg', 'png')):
            image_path = os.path.join(root, file)
            print(f"Processing {image_path}")
            detect_faces(image_path)
# Out:
# Processing C:\Users\nirma\Downloads\archive (10)\images\cat.jpg
# Processing C:\Users\nirma\Downloads\archive (10)\images\pexels-katerina-holmes-5905497.jpg
# Processing C:\Users\nirma\Downloads\archive (10)\images\pexels-olly-3807758.jpg
# Processing C:\Users\nirma\Downloads\archive (10)\images\pexels-olly-733872.jpg
# Processing C:\Users\nirma\Downloads\archive (10)\images\pexels-pixabay-415829.jpg
